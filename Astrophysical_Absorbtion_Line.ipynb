# %% [markdown]
# # Performing Final Calculations for evaluating the value of Intensity by inputing varying value of v (frequency)

# %%
v0 = 2.46607e15
T = 6.265e8
f = 0.4164
g0 = 2
z = 2.00
me = 9.11e-28
c = 3.00e10
e = 4.80e-10 
nh = 0.1 
x = 0.1
a=(e**2)*f*nh*(1-x)*g0
b=12.56*me*c*z
c=a/b

T = 6.265e8
v =  2.99e14
v0 = 2.46632e15


val = ((v-v0)**2)+((T/12.56)**2)



d=T/val

alpha=c*d
 
from math import exp
from decimal import *

alpha =-alpha
d = 1e14

# %% [markdown]
# # Plotting the graphs

# %% [markdown]
# Initially calculating the values of Intensity for corresponding wavelengths and then plotting Intensity vs wavelength (in nm)

# %%
lamda_14_1 = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000 ]
I_14_1 = [0.9999999999942590367396633155294694006443023681640625, 0.99999999999834587871561097927042283117771148681640625, 0.99999999999926780791525970926159061491489410400390625, 0.9999999999994655386359454496414400637149810791015625, 0.99999999999954791718437263625673949718475341796875, 0.999999999999592770194567492580972611904144287109375, 0.99999999999962063679248558401013724505901336669921875,0.99999999999963995467311406173394061625003814697265625, 0.9999999999996536104163169511593878269195556640625,
      0.99999999999966437957965581517782993614673614501953125]
      
lamda_18_1 = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000 ]
I_18_1 = [0.99999994259087021664100802809116430580615997314453125, 0.9999999834588546576696899137459695339202880859375, 0.99999999267806549685388972648070193827152252197265625, 0.99999999465495326145259014083421789109706878662109375, 0.99999999547929352416986148455180227756500244140625, 0.99999999592724886365857628334197215735912322998046875,0.999999996206069940996030709357000887393951416015625,0.99999999639939829432222495597670786082744598388671875, 0.9999999965364831933101186223211698234081268310546875,
      0.9999999966443116061753926260280422866344451904296875] 
      
lamda_21_1 = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000 ]
I_21_1 = [0.9999425925164882045237391139380633831024169921875, 0.9999834589913800808602672987035475671291351318359375, 0.9999926780923538149892237925087101757526397705078125, 0.999994654967531371170252896263264119625091552734375, 0.999995479303763534772997445543296635150909423828125, 0.99999592725710273466432909117429517209529876708984375, 0.9999962060771707683670683763921260833740234375,0.9999963994047533777376202124287374317646026611328125, 0.9999965364892358099524471981567330658435821533203125,
      0.99999664431720980406481658064876683056354522705078125 ] 
 
 
lamda_14_2 = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000 ]
I_14_2 = [0.99999999999425359664684265226242132484912872314453125, 0.9999999999983467668940306793956551700830459594726562, 0.99999999999926802995986463429289869964122772216796875, 0.99999999999946564965824791215709410607814788818359375, 0.99999999999954802820667509877239353954792022705078125, 0.99999999999959288121686995509662665426731109619140625, 0.99999999999962074781478804652579128742218017578125,0.9999999999996400656954165242495946586132049560546875, 0.99999999999965372143861941367504186928272247314453125,
      0.9999999999996644906019582776934839785099029541015625 ]
      
lamda_18_2 = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000 ]
I_18_2 = [0.9999999425360439619936414601397700607776641845703125, 0.999999983467324771169160158024169504642486572265625, 0.99999999268056039003482737825834192335605621337890625, 0.99999999465650935004390476024127565324306488037109375, 0.9999999954805038893113078302121721208095550537109375, 0.99999999592828381356213185426895506680011749267578125, 0.9999999962070005299352715155691839754581451416015625,0.999999996400258606144006989779882133007049560546875, 0.9999999965372949883857245367835275828838348388671875,
      0.9999999966450856536681612851680256426334381103515625 ] 
      
lamda_21_2 = [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000 ]
I_21_2 = [0.99994253769337426707153326788102276623249053955078125, 0.999983467461325492564583328203298151493072509765625, 0.99999268058712564855028404053882695734500885009765625, 0.9999946565236272899568348293541930615901947021484375, 0.999995480514156875884168584889266639947891235351562, 0.99999592829213412858990750464727170765399932861328125, 0.99999620700776137294241152631002478301525115966796875,0.99999640026513170187882906247978098690509796142578125, 0.9999965373009522817682181994314305484294891357421875,
      0.99999664509131880318903995430446229875087738037109375 ]

# %%
 import matplotlib.pyplot as plt
plt.plot(lamda_14_1,I_14_1)
plt.title("d=1e14 cm")
plt.xlabel("Wavelength(in nm)")
plt.ylabel("Intensity")
plt.show()

# %%
 import matplotlib.pyplot as plt
plt.plot(lamda_14_2,I_14_2)
plt.title("d=1e14 cm")
plt.xlabel("Wavelength(in nm)")
plt.ylabel("Intensity")
plt.show()

# %%
 import matplotlib.pyplot as plt
plt.plot(lamda_18_1,I_18_1,color='r')
plt.title("d=1e18 cm")
plt.xlabel("Wavelength(in nm)")
plt.ylabel("Intensity")
plt.show()

# %%
 import matplotlib.pyplot as plt
plt.plot(lamda_18_2,I_18_2,color='r')
plt.title("d=1e18 cm")
plt.xlabel("Wavelength(in nm)")
plt.ylabel("Intensity")
plt.show()

# %%
 import matplotlib.pyplot as plt
plt.plot(lamda_21_1,I_21_1,color='g')
plt.title("d=1e21 cm")
plt.xlabel("Wavelength(in nm)")
plt.ylabel("Intensity")
plt.show()

# %%
 import matplotlib.pyplot as plt
plt.plot(lamda_21_2,I_21_2,color='g')
plt.title("d=1e21 cm")
plt.xlabel("Wavelength(in nm)")
plt.ylabel("Intensity")
plt.show()
